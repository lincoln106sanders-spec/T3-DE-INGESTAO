# %% [markdown]
# 'Execucao' = pipeline principal (roda todas as 6 coleções)

# %%
# %pip install pymongo

# %%
dbutils.library.restartPython()

# %%
import sys

sys.path.append("/Workspace/trabalho_ing_de_dados/T3-DE-INGESTAO/src")

from ingestion_job import run_all

# %%
resultados = run_all("/Workspace/trabalho_ing_de_dados/T3-DE-INGESTAO/config/collections.json",
                     spark,
                     dbutils,
                    )
resultados
