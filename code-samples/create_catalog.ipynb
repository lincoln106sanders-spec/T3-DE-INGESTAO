-- %%
create catalog meu_catalog

-- %%
create schema meu_catalog.landing

-- %%
create volume meu_catalog.landing.olist

-- %%
create volume meu_catalog.landing.postgres

-- %%
neondb_owner
npg_Aqh1cuyMzX8b

-- %%
-- postgresql://neondb_owner:SENHA@ep-bitter-voice-ax3yfhlz-pooler.c-4.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require
